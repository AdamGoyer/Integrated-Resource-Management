# %% [markdown]
# # Client Onboarding Template
#
# ### Financial Planning Client Onboarding Framework
#
# #### **Objective:**
# To create an engaging and efficient client onboarding experience that combines digital tools and conversational AI to collect comprehensive financial information while ensuring a client-centric approach.
#
# ---
#
# ### **Scope of the Project**
# 1. **Objective:** To develop a digital and conversational onboarding system that:
#    - Collects detailed client financial and personal data.
#    - Simulates a human advisor’s conversational style.
#    - Generates a client file for analysis and planning.
#    - Seamlessly integrates with existing financial tools (e.g., eMoney, MassMutual).
#
# 2. **Technological Approach:**
#    - Use a combination of real-time AI tools (e.g., ChatGPT, Hume.ai) for dynamic conversations.
#    - Implement a digital fact-finder as a backup or supplementary tool.
#    - Ensure compatibility with mobile, desktop, and tablet devices.
#
# 3. **Target Audience:**
#    - New clients seeking financial planning.
#    - Returning clients updating their information.
#
# 4. **Compliance:**
#    - Ensure the system meets regulatory requirements (FINRA, SEC).
#    - Incorporate data privacy and security protocols (e.g., GDPR, CCPA).
#
# ---
#
# ### **Questions and Data Collection Goals**
#
# #### **Personal Information**
# 1. **Client Details:**
#    - Full Name, DOB, Citizenship Status.
#    - Address, Contact Information.
#    - Employment Information (Employer, Title, Years at Job).
#
# 2. **Spouse/Partner Details:**
#    - Full Name, DOB, Citizenship Status.
#    - Employment Information.
#
# 3. **Family Details:**
#    - Children (Names, DOBs, Dependency Status).
#    - Other Dependents or Special Circumstances.
#
# #### **Financial Overview**
# 1. **Income:**
#    - Annual Salary, Bonuses, Other Income.
#    - Social Security Benefits (Current or Projected).
#    - Pension Details.
#
# 2. **Expenses:**
#    - Monthly Living Expenses.
#    - Discretionary Spending (e.g., vacations, hobbies).
#    - Anticipated Changes in Retirement.
#
# 3. **Assets:**
#    - Real Estate (Address, Current Value, Purchase Price).
#    - Investments (401(k), IRAs, Brokerage Accounts).
#    - Cash Accounts (Checking, Savings).
#
# 4. **Liabilities:**
#    - Mortgages (Balance, Term, Interest Rate).
#    - Other Loans (Student, Auto, HELOC).
#    - Credit Card Balances.
#
# #### **Insurance**
# 1. **Current Policies:**
#    - Life Insurance (Term, Whole, Death Benefit).
#    - Disability Insurance (Benefit Amount, Waiting Period).
#    - Long-Term Care (Coverage Amount, Premiums).
#
# 2. **Future Needs:**
#    - Is current coverage sufficient?
#    - Interest in reviewing additional options?
#
# #### **Goals and Risk Tolerance**
# 1. **Short-Term Goals:**
#    - Debt Reduction, Emergency Fund.
#    - Major Purchases (Home, Vehicle).
#
# 2. **Long-Term Goals:**
#    - Retirement Age and Lifestyle Expectations.
#    - Education Funding for Children.
#    - Estate Planning and Legacy Goals.
#
# 3. **Risk Tolerance:**
#    - Conservative, Moderate, Aggressive.
#
# #### **Estate Planning**
# 1. **Current Documents:**
#    - Wills, Trusts, Power of Attorney.
#
# 2. **Future Planning:**
#    - Gifting or Charitable Contributions.
#    - Guardianship Provisions.
#
# #### **Advisor-Specific Questions**
# 1. **Decision-Making:**
#    - Do you work with a CPA or attorney?
#    - Are these professionals key decision-makers?
#
# 2. **Obstacles:**
#    - What’s your biggest challenge in achieving your financial goals?
#    - Are you willing to invest effort or funds in tax-saving strategies?
#
# ---
#
# ### **Conversational AI Features**
# 1. **Dynamic Questions:**
#    - Adjust follow-up questions based on client responses.
#    - E.g., If a client has no dependents, skip related sections.
#
# 2. **Empathy and Engagement:**
#    - Use conversational tones to put clients at ease.
#    - Provide positive feedback (e.g., “That’s a great start!”).
#
# 3. **Real-Time Clarifications:**
#    - Clarify ambiguous answers immediately (e.g., “When you say you’re planning to retire early, what age are you thinking of?”).
#
# 4. **Summary and Confirmation:**
#    - Summarize collected data at the end for client approval.
#
# ---
#
# ### **Next Steps**
# 1. Develop a digital prototype of the onboarding questionnaire.
# 2. Create a conversation flow for the AI-based tool.
# 3. Integrate into existing CRM and financial tools.
# 4. Pilot with a small group of clients and gather feedback.

# %% [markdown]
# ### **Conversational Script**
#
# #### **Introduction**
# - "Hi [Client Name], I’m here to guide you through a few questions to better understand your financial situation and goals. This will only take about 20 minutes, and I’ll make sure we focus on what’s most important to you."
# - "Feel free to ask for clarification at any time or let me know if you’d like to skip a question."
#
# #### **Personal Information**
# 1. "Let’s start with some basics. Can you tell me your full name and date of birth?"
# 2. "Do you live in the U.S.? If so, what’s your home address?"
# 3. "Are you currently employed? What’s your job title and how long have you been there?"
#
# #### **Spouse/Partner Details**
# 1. "Do you have a spouse or partner you’d like included in this plan? If yes, what’s their name and date of birth?"
# 2. "Are they employed? What do they do for work?"
#
# #### **Family Details**
# 1. "Do you have any children or dependents? If yes, what are their names and ages?"
# 2. "Are there any special circumstances we should consider, such as educational or medical needs?"
#
# #### **Financial Overview**
# 1. "Let’s talk about income. What’s your annual salary or income? Do you receive any bonuses or other sources of income?"
# 2. "Do you currently receive Social Security or pension income? If not, do you have any projections for when you might?"
# 3. "What about your expenses—how much do you spend monthly on essentials like housing, utilities, and groceries?"
#
# #### **Assets and Liabilities**
# 1. "Do you own any property, like a home or rental property? If so, can you tell me about its current value?"
# 2. "What investments do you currently have? These could be retirement accounts like a 401(k) or brokerage accounts."
# 3. "Do you have any debts we should consider, such as a mortgage, auto loan, or credit card balances?"
#
# #### **Insurance**
# 1. "Do you currently have life insurance or disability coverage? If yes, what are the coverage amounts?"
# 2. "Are you interested in exploring any additional coverage options?"
#
# #### **Goals and Risk Tolerance**
# 1. "What are your short-term financial goals? For example, are you saving for a big purchase or paying down debt?"
# 2. "What about long-term goals? Do you have a specific retirement age in mind or plans to support your children’s education?"
# 3. "How would you describe your comfort level with financial risk: conservative, moderate, or aggressive?"
#
# #### **Estate Planning**
# 1. "Do you have a will or trust in place?"
# 2. "Are there any charitable organizations you’d like to include in your plans?"
#
# #### **Wrap-Up**
# - "Thank you for sharing this information. I’ll compile everything we discussed and create a personalized financial plan for you. Is there anything else you’d like to add before we finish?"
# - "You’ll receive a summary shortly to review and confirm. I’m here if you have any questions in the meantime!"
#
# ---
#
# ### **Next Steps**
# 1. Test the script with a small group of users.
# 2. Adjust the conversation flow based on feedback.
# 3. Implement into the digital onboarding tool and integrate with financial planning systems.
